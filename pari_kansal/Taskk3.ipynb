# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df =pd.read_csv(r"C:\Users\Sarvesh\Downloads\DataClean - DataClean.csv.csv")
df.columns
# Out:
# Index(['Unnamed: 0', 'brand', 'model', 'transmission', 'age', 'fuel', 'engine',
#        'Distance', 'owner', 'price', 'location', 'mileage', 'power', 'seats',
#        'type'],
#       dtype='object')

# %%
df.shape
# Out:
# (32200, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32200 entries, 0 to 32199
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    32200 non-null  int64
#  1   brand         32199 non-null  object
#  2   model         32199 non-null  object
#  3   transmission  32200 non-null  object
#  4   age           32199 non-null  float64
#  5   fuel          32200 non-null  object
#  6   engine        24068 non-null  float64
#  7   Distance      32200 non-null  object
#  8   owner         16819 non-null  float64
#  9   price         32200 non-null  int64
#  10  location      13801 non-null  object
#  11  mileage       21380 non-null  float64
#  12  power         21273 non-null  float64
#  13  seats         29353 non-null  float64
#  14  type          8015 non-null   object
# dtypes: float64(6), int64(2), object(7)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine           8132
# Distance            0
# owner           15381
# price               0
# location        18399
# mileage         10820
# power           10927
# seats            2847
# type            24185
# dtype: int64

# %%
#To calculate the percentage of missing data
df.isnull().sum()/df.shape[0]*100
# Out:
# Unnamed: 0       0.000000
# brand            0.003106
# model            0.003106
# transmission     0.000000
# age              0.003106
# fuel             0.000000
# engine          25.254658
# Distance         0.000000
# owner           47.767081
# price            0.000000
# location        57.139752
# mileage         33.602484
# power           33.934783
# seats            8.841615
# type            75.108696
# dtype: float64

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
#as 75% of data is missing
data.drop(columns=['type'])
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance  owner    price       location  mileage  \
# ...

# %%
#as more than 50% data is also missing in location column
data.drop(columns=['location'])
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine           Distance  owner    price  mileage   power  seats  \
# ...

# %%
num_duplicates = df.duplicated().sum()
print(num_duplicates)
# Out:
# 0

# %%
df.describe()
#to know about count and many other information like mean and standard deviation
# Out:
#         Unnamed: 0           age        engine         owner         price  \
# count  32200.00000  32199.000000  24068.000000  16819.000000  3.220000e+04
# mean   16099.50000      7.120625   1489.872569      1.263452  7.347001e+05
# std     9295.48367      3.485577    520.916872      0.490463  7.037702e+05
# min        0.00000      0.000000     72.000000      1.000000  4.000000e+04
# 25%     8049.75000      4.000000   1197.000000      1.000000  3.850000e+05
# 50%    16099.50000      7.000000   1248.000000      1.000000  5.510000e+05
# 75%    24149.25000      9.000000   1591.000000      1.000000  7.920000e+05
# max    32199.00000     29.000000   5998.000000      4.000000  7.066000e+06
#
#             mileage         power         seats
# count  21380.000000  21273.000000  29353.000000
# mean      19.305532    103.497647      5.233537
# std        4.418605     45.002260      0.707639
# min        0.000000     34.200000      0.000000
# 25%       16.500000     74.000000      5.000000
# ...

# %%
#to know about descriptive statistics of column named object
df.describe(include="object")
#top = the most frequent value in the model
#frequency = the most common value
# Out:
#          brand  model transmission    fuel    Distance     location       type
# count    32199  32199        32200   32200       32200        13801       8015
# unique      35    301           10       5       16575           26          5
# top     maruti  swift       manual  petrol  50000.0 KM  maharashtra  hatchback
# freq     10561   1863        24599   19155         546         1427       5080

# %%
for i in df.select_dtypes(include="float").columns:
    sns.histplot(data=df,x=i)
    plt.show()

# %%
#Dont understand how to read an analyse boxplot and about outliers
for i in df.select_dtypes(include="float").columns:
    sns.boxplot(data=df,x=i)
    plt.show()

# %%
plt.scatter(data=df,x='Distance',y='owner')

# %%
plt.figure(figsize=(15,8))
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(),annot = True,cmap="YlGnBu")
plt.show()

# %%
df['engine'].fillna(df['engine'].median(),inplace=True)
# Out:
# C:\Users\Sarvesh\AppData\Local\Temp\ipykernel_23156\4125795703.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['engine'].fillna(df['engine'].median(),inplace=True)

# %%
df['age'].fillna(df['age'].median(),inplace=True)
# Out:
# C:\Users\Sarvesh\AppData\Local\Temp\ipykernel_23156\2790788646.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine              0
# Distance            0
# owner           15381
# price               0
# location        18399
# mileage         10820
# power           10927
# seats            2847
# type            24185
# dtype: int64

# %%
df.shape
# Out:
# (32199, 15)

# %%
nan_values = df[df['brand'].isna()]
print(nan_values)
# Out:
#       Unnamed: 0 brand model transmission  age    fuel  engine    Distance  \
# 1817        1817   NaN   NaN    automatic  NaN  petrol  1248.0  13794.0 KM
#
#       owner   price location  mileage  power  seats   type
# 1817    1.0  976000    delhi      NaN    NaN    5.0  sedan

# %%
nan_values = df[df['model'].isna()]
print(nan_values)
# Out:
#       Unnamed: 0 brand model transmission  age    fuel  engine    Distance  \
# 1817        1817   NaN   NaN    automatic  NaN  petrol  1248.0  13794.0 KM
#
#       owner   price location  mileage  power  seats   type
# 1817    1.0  976000    delhi      NaN    NaN    5.0  sedan

# %%
df=df.drop(index=1817)

# %%
df.shape
# Out:
# (32199, 15)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               0
# model               0
# transmission        0
# age                 0
# fuel                0
# engine              0
# Distance            0
# owner               0
# price               0
# location        18399
# mileage             0
# power               0
# seats               0
# type            24185
# dtype: int64

# %%
df.head(20)
# Out:
#     Unnamed: 0          brand     model transmission   age    fuel  engine  \
# 0            0     volkswagen      ameo       manual   8.0  diesel  1248.0
# 1            1        renault    duster       manual   8.0  diesel  1461.0
# 2            2           land     rover    automatic  21.0  diesel  1197.0
# 3            3  mercedes-benz       new    automatic  10.0  diesel  2143.0
# 4            4         maruti      alto       manual   4.0     cng  1248.0
# 5            5        hyundai       i20       manual   4.0  petrol  1197.0
# 6            6           audi        a4    automatic  11.0  petrol  1984.0
# 7            7         maruti     swift       manual   9.0  petrol  1197.0
# 8            8          honda      city       manual  11.0  diesel  1248.0
# 9            9         maruti  alto k10       manual  13.0  petrol  1248.0
# 10          10          honda      city       manual   5.0  petrol  1497.0
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               0
# model               0
# transmission        0
# age                 0
# fuel                0
# engine              0
# Distance            0
# owner               0
# price               0
# location        18399
# mileage             0
# power               0
# seats               0
# type            24185
# dtype: int64

# %%
#i have done nothing in mileage and power but it is now showing no missing value here...idk why..
#although i have drop both the colmuns location and type but it is showing here and 
# rest of the data dont have any missing value now

# %%
def convert_to_km(row):
    value,unit =row.split()
    value =float(value)
    if unit =='Metres':
        return value*0.001
    elif unit =='Miles':
        return value*1.60934
    else:
        return value
df['Distance_KM']=df['Distance'].apply(convert_to_km)
df=df.drop(columns=['Distance'])
df
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       manual   8.0  diesel
# 1               1        renault      duster       manual   8.0  diesel
# 2               2           land       rover    automatic  21.0  diesel
# 3               3  mercedes-benz         new    automatic  10.0  diesel
# 4               4         maruti        alto       manual   4.0     cng
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       manual  15.0  petrol
# 32196       32196     volkswagen       vento       manual   8.0  petrol
# 32197       32197            bmw           5    automatic   8.0  diesel
# 32198       32198        hyundai  new santro       manual   3.0  petrol
# 32199       32199          honda        city       manual   9.0  petrol
#
#        engine  owner    price       location  mileage   power  seats  \
# ...

# %%
df.shape
max_nans_allowed = 5
deleted_rows = df[df.isnull().sum(axis=1) > max_nans_allowed]
print(deleted_rows)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, brand, model, transmission, age, fuel, engine, Distance, owner, price, location, mileage, power, seats, type]
# Index: []

# %%
df['transmission'].unique()
# Out:
# array(['manual', 'automatic', 'stick shift', 'gear shift', 'lever shift',
#        'StIcKsHiFt', 'automated', 'auto', 'non gear', 'non-clutch'],
#       dtype=object)

# %%
df['transmission']=df['transmission'].map({
    'manual':'Manual','automatic':'Automatic','stick shift':'Manual','gear shift':'Manual','lever shift':'Manual',
    'StIcKsHiFt':'Manual','automated':'Automatic','auto':'Automatic','non gear':'Automatic',
    'non-clutch':'Automatic'
})

# %%
df['transmission']
# Out:
# 0           Manual
# 1           Manual
# 2        Automatic
# 3        Automatic
# 4           Manual
#            ...
# 32195       Manual
# 32196       Manual
# 32197    Automatic
# 32198       Manual
# 32199       Manual
# Name: transmission, Length: 32200, dtype: object

# %%
df.isnull().sum()
#RESOLVED but now i have droped the row having nan value in brand and model now it is howing nan value in both these columns..
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine              0
# owner           15381
# price               0
# location        18399
# mileage         10820
# power           10927
# seats            2847
# type            24185
# Distance_KM         0
# dtype: int64

# %%
df.drop(columns=['type'], inplace=True)

# %%
df.drop(columns=['location'],inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0          brand   model transmission   age    fuel  engine  \
# 0           0     volkswagen    ameo       Manual   8.0  diesel  1248.0
# 1           1        renault  duster       Manual   8.0  diesel  1461.0
# 2           2           land   rover    Automatic  21.0  diesel  1197.0
# 3           3  mercedes-benz     new    Automatic  10.0  diesel  2143.0
# 4           4         maruti    alto       Manual   4.0     cng  1248.0
#
#    owner    price  mileage   power  seats  Distance_KM
# 0    1.0   876000      NaN     NaN    5.0      52858.0
# 1    NaN   315000    19.64  108.45    5.0      54000.0
# 2    2.0  1611000     0.00   74.00    NaN      75000.0
# 3    1.0  1795000    19.27  170.00    5.0   44965000.0
# 4    1.0   445000      NaN     NaN    5.0      27993.0

# %%
df.tail()
# Out:
#        Unnamed: 0       brand       model transmission   age    fuel  engine  \
# 32195       32195     hyundai      santro       Manual  15.0  petrol  1086.0
# 32196       32196  volkswagen       vento       Manual   8.0  petrol  1598.0
# 32197       32197         bmw           5    Automatic   8.0  diesel  1995.0
# 32198       32198     hyundai  new santro       Manual   3.0  petrol  1248.0
# 32199       32199       honda        city       Manual   9.0  petrol  1497.0
#
#        owner    price  mileage  power  seats  Distance_KM
# 32195    2.0   155000    17.92   62.1    5.0     136642.0
# 32196    NaN   550000    15.04  103.6    5.0      44000.0
# 32197    NaN  1575000    18.12  190.0    5.0      69000.0
# 32198    1.0   520000      NaN    NaN    5.0      16502.0
# 32199    NaN   400000    16.80  116.3    5.0      43120.0

# %%
#to fill the column owner by applying conditions
df['owner'].unique()
# Out:
# array([ 1., nan,  2., 11.,  9.,  3., 10., 13., 15., 12.,  4., 17., 22.,
#        14., 16., 21., 18., 29., 25., 19.])

# %%
ages_where_owner_is_1 = df.loc[df['owner'] == 1, 'age']
print(ages_where_owner_is_1)
plt.hist(ages_where_owner_is_1, bins=10)
# Out:
# 0         8.0
# 3        10.0
# 4         4.0
# 9        13.0
# 13        6.0
#          ...
# 32186     4.0
# 32190    11.0
# 32193     7.0
# 32194    11.0
# 32198     3.0
# Name: age, Length: 12769, dtype: float64
# (array([ 626., 2749., 2986., 3765., 1455.,  950.,  180.,   41.,   12.,
#            4.]),
#  array([ 0. ,  2.6,  5.2,  7.8, 10.4, 13. , 15.6, 18.2, 20.8, 23.4, 26. ]),
#  <BarContainer object of 10 artists>)

# %%
ages_where_owner_is_2 = df.loc[df['owner'] == 2, 'age']
print(ages_where_owner_is_2)
plt.hist(ages_where_owner_is_2, bins=10)
# Out:
# 2        21.0
# 22        9.0
# 29        6.0
# 37       12.0
# 46        2.0
#          ...
# 32170     5.0
# 32172     8.0
# 32175    18.0
# 32182    12.0
# 32195    15.0
# Name: age, Length: 4817, dtype: float64
# (array([1318.,  459., 1240.,  644.,  716.,  229.,  156.,   38.,   13.,
#            4.]),
#  array([ 1. ,  3.5,  6. ,  8.5, 11. , 13.5, 16. , 18.5, 21. , 23.5, 26. ]),
#  <BarContainer object of 10 artists>)

# %%
ages_where_owner_is_3 = df.loc[df['owner'] == 3, 'age']
print(ages_where_owner_is_3)
plt.plot(ages_where_owner_is_3)
# Out:
# 8        11.0
# 11        3.0
# 14       18.0
# 52        3.0
# 85        3.0
#          ...
# 32131     3.0
# 32139     3.0
# 32160     3.0
# 32188     3.0
# 32189    12.0
# Name: age, Length: 2280, dtype: float64

# %%
ages_where_owner_is_4 = df.loc[df['owner'] == 4, 'age']
print(ages_where_owner_is_4)
plt.hist(ages_where_owner_is_4, bins=10)
# Out:
# 5        4.0
# 12       4.0
# 45       4.0
# 59       4.0
# 60       4.0
#         ...
# 32105    4.0
# 32115    4.0
# 32176    4.0
# 32178    4.0
# 32183    4.0
# Name: age, Length: 2255, dtype: float64
# (array([2.245e+03, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 2.000e+00,
#         4.000e+00, 2.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 4. ,  5.9,  7.8,  9.7, 11.6, 13.5, 15.4, 17.3, 19.2, 21.1, 23. ]),
#  <BarContainer object of 10 artists>)

# %%
df.loc[(df['age']>3) & (df['age']<13) & (df['price']>5500000) & (df['owner'].isna()), 'owner'] = 1
df.loc[(df['age']>5) & (df['age']<21) & (df['price']>1800000) & (df['owner'].isna()), 'owner'] = 2
df.loc[(df['age']>3) & (df['age']<18) & (df['price']>700000) & (df['owner'].isna()), 'owner'] = 3
df.loc[(df['age']==4) & (df['price']<=700000) & (df['owner'].isna()), 'owner'] = 4

# %%
df['owner']
# Out:
# 0        1.0
# 1        8.0
# 2        2.0
# 3        1.0
# 4        1.0
#         ...
# 32195    2.0
# 32196    8.0
# 32197    8.0
# 32198    1.0
# 32199    9.0
# Name: owner, Length: 32200, dtype: float64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine              0
# owner               0
# price               0
# mileage         10820
# power           10927
# seats            2847
# Distance_KM         0
# dtype: int64

# %%
rows_with_seats_7 = df[df['seats'] == 7]
print(rows_with_seats_7)
# Out:
#        Unnamed: 0     brand     model transmission   age    fuel  engine  \
# 25             25    maruti    ertiga       Manual   6.0  diesel  1248.0
# 49             49   hyundai     santa       Manual  11.0  diesel  2199.0
# 62             62  mahindra    xuv500       Manual   3.0  diesel  1248.0
# 72             72    maruti    ertiga       Manual   8.0  diesel  1248.0
# 86             86    maruti    ertiga       Manual   3.0  diesel  1248.0
# ...           ...       ...       ...          ...   ...     ...     ...
# 32102       32102  mahindra    xuv500       Manual   4.0  diesel  2179.0
# 32115       32115  mahindra    xuv500    Automatic   4.0  diesel  2179.0
# 32125       32125    toyota  fortuner       Manual   9.0  diesel  2982.0
# 32126       32126  mahindra   scorpio       Manual   7.0  diesel  2179.0
# 32178       32178    toyota    innova       Manual   4.0  diesel  2393.0
#
#        owner    price  mileage   power  seats   Distance_KM
# ...

# %%
df['seats'] = np.where((df['engine'] == 1248) | (df['engine'] > 2100),
                        df['seats'].fillna(7),
                          df['seats'].fillna(5))
#df.loc[(df['engine']==1248) | (df['engine'] >2100) & (df['seats'].isna()), 'seats'] = 7
#df.loc[(df['seats']),'seats'] = 5
# Out:
# C:\Users\Sarvesh\AppData\Local\Temp\ipykernel_23156\3739503319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['seats'] = np.where((df['engine'] == 1248) | (df['engine'] > 2100),

# %%
df['seats']
# Out:
# 0        5.0
# 1        5.0
# 3        5.0
# 4        5.0
# 5        5.0
#         ...
# 32195    5.0
# 32196    5.0
# 32197    5.0
# 32198    5.0
# 32199    5.0
# Name: seats, Length: 32059, dtype: float64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine              0
# owner               0
# price               0
# mileage         10820
# power           10824
# seats               0
# Distance_KM         0
# dtype: int64

# %%
nan_brand = df[df['brand'].isna()]
print(nan_brand)
# Out:
#       Unnamed: 0 brand model transmission  age    fuel  engine  owner   price  \
# 1817        1817   NaN   NaN    Automatic  NaN  petrol  1248.0    1.0  976000
#
#       mileage  power  seats  Distance_KM
# 1817      NaN    NaN    7.0      13794.0

# %%
nan_model=df[df['model'].isna()]
print(nan_model)
# Out:
#       Unnamed: 0 brand model transmission  age    fuel  engine  owner   price  \
# 1817        1817   NaN   NaN    Automatic  NaN  petrol  1248.0    1.0  976000
#
#       mileage  power  seats  Distance_KM
# 1817      NaN    NaN    7.0      13794.0

# %%
nan_age=df[df['age'].isna()]
print(nan_age)
# Out:
#       Unnamed: 0 brand model transmission  age    fuel  engine  owner   price  \
# 1817        1817   NaN   NaN    Automatic  NaN  petrol  1248.0    1.0  976000
#
#       mileage  power  seats  Distance_KM
# 1817      NaN    NaN    7.0      13794.0

# %%
df.drop(index=1817)
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       Manual   8.0  diesel
# 1               1        renault      duster       Manual   8.0  diesel
# 3               3  mercedes-benz         new    Automatic  10.0  diesel
# 4               4         maruti        alto       Manual   4.0     cng
# 5               5        hyundai         i20       Manual   4.0  petrol
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       Manual  15.0  petrol
# 32196       32196     volkswagen       vento       Manual   8.0  petrol
# 32197       32197            bmw           5    Automatic   8.0  diesel
# 32198       32198        hyundai  new santro       Manual   3.0  petrol
# 32199       32199          honda        city       Manual   9.0  petrol
#
#        engine  owner    price  mileage   power  seats  Distance_KM
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine              0
# owner               0
# price               0
# mileage         10820
# power           10824
# seats               0
# Distance_KM         0
# dtype: int64

# %%
df_cleaned = df.dropna(subset=['brand', 'model', 'age'])
print(df_cleaned)
# Out:
#        Unnamed: 0          brand       model transmission   age    fuel  \
# 0               0     volkswagen        ameo       Manual   8.0  diesel
# 1               1        renault      duster       Manual   8.0  diesel
# 3               3  mercedes-benz         new    Automatic  10.0  diesel
# 4               4         maruti        alto       Manual   4.0     cng
# 5               5        hyundai         i20       Manual   4.0  petrol
# ...           ...            ...         ...          ...   ...     ...
# 32195       32195        hyundai      santro       Manual  15.0  petrol
# 32196       32196     volkswagen       vento       Manual   8.0  petrol
# 32197       32197            bmw           5    Automatic   8.0  diesel
# 32198       32198        hyundai  new santro       Manual   3.0  petrol
# 32199       32199          honda        city       Manual   9.0  petrol
#
#        engine  owner    price  mileage   power  seats  Distance_KM
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# brand               1
# model               1
# transmission        0
# age                 1
# fuel                0
# engine              0
# owner               0
# price               0
# mileage         10820
# power           10824
# seats               0
# Distance_KM         0
# dtype: int64

# %%
df.plot(x='mileage', y='power',kind='scatter') 
plt.xlabel('Mileage')
plt.ylabel('Power')
plt.title('Mileage vs Power')
plt.show()
